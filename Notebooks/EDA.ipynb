# %% [markdown]
# # EDA
#
# This first step is focused on boiling the corpus down to a digestible format that can be handled by nlp paradigms.

# %%
import pandas as pd
import numpy as np
import openai
import re 
import os
import glob
import json
import seaborn as sns
import matplotlib.pyplot as plt
from cleaning_helpers import *

# %% [markdown]
# ## Loading and Cleaning

# %%
import os
import pandas as pd


def process_all_txt_files(input_dir: str, output_dir: str) -> pd.DataFrame:
    """
    Process all .txt files in `input_dir`:
    1. Clean each file using clean_file
    2. Save cleaned version in output_dir
    3. Process cleaned file into sentences using process_txt_file
    4. Concatenate all results into a single DataFrame
    """
    all_dfs = []

    # Make sure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            cleaned_filename = os.path.splitext(filename)[0] + "_cleaned.txt"
            cleaned_path = os.path.join(output_dir, cleaned_filename)

            # Step 1: Clean the file
            clean_file(input_path, cleaned_path)

            # Step 2: Process cleaned file into sentences
            df = process_txt_file(cleaned_path)

            # Optional: add a column for original file name
            df["source_file"] = filename

            all_dfs.append(df)

    # Step 3: Concatenate all DataFrames
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
    else:
        combined_df = pd.DataFrame(columns=["page", "sentence", "source_file"])

    return combined_df


# Example usage
input_dir = r"C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/"
output_dir = r"C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/"

corpus = process_all_txt_files(input_dir, output_dir)
print(corpus.head(20))
# Out:
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak10_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak10_clean_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak2_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak3_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak4_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak5_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak6_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak7_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak8_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divan_Prak9_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Divasn_Prak1_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԱԿՈՒՆՔ-ԵՎ-ԿԱԹՆԱՂԲՅՈՒՐ-ԳՅՈՒՂԵՐԻ-ՊԱՏՄԱԿԱՆ-ՀՈՒՇԱՐՁԱՆՆԵՐԸ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԱՆՏԻՊ ՎԻՄԱԳՐԵՐ ԵՐԵՎԱՆԻ ԿԱԹՈՂԻԿԵ ԵԿԵՂԵՑՈՒՑ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԱՐՄԱՎԻՐԻ ՄԱՐԶԻ ՎԻՄԱԳՐԱԿԱՆ ԺԱՌԱՆԳ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԱՐՑԱԽԻ-ԵՎ-ՍՅՈՒՆԻՔԻ-ՄԵԼԻՔԱԿԱՆ-ԱՊԱՐԱՆՔՆԵՐԸ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Բուն-Աղվանք-1_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԴԱԴԻ-ՎԱՆՔԻ-ՎԵՐԱԿԱՆԳՆՈՒՄԸ-1997-2011-ԹԹ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԷՋՄԻԱԾՆԻ ՏԱՊԱՆԱԳՐԵՐ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Խոջիվանք_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ԿՈՎԿԱՍՅԱՆ-ԹԱՆԳԱՐԱՆԻ-ՀԱՅԿԱԿԱՆ-ՀԱՎԱՔԱԾՈՒՆ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՀԱԼԵՊԻ-ԱՐՁԱՆԱԳՐՈՒԹՅՈՒՆՆԵՐԸ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՀԱՅ-ՄՇԱԿՈՒՅԹԻ-ՀՈՒՇԱՐՁԱՆՆԵՐԸ-ԽՈՐՀՐԴԱՅԻՆ-ԱԴՐԲԵՋԱՆԻՆ-ԲՌՆԱԿՑՎԱԾ-ՇՐՋԱՆՆԵՐՈՒՄ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՀԱՅԵՐԷՆ ՏԱՊԱՆԱԳՐԵՐ ԲԵԼԳՐԱԴԻՑ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Հնդկաստանի-վիմագրեր_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՆՈՐԱԳԱՎԻԹ ԲՆԱԿԱՎԱՅՐԸ ԵՎ  Ս. ԳԵՎՈՐԳ ԵԿԵՂԵՑՈՒ ՎԻՄԱԳՐԵՐԸ _cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՊԱՏՄԱՄՇԱԿՈՒԹԱՅԻՆ ԺԱՌԱՆԳՈՒԹՅՈՒՆ ՄԱՏԵՆԱՇԱՐ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՍԻՍԻԱՆԻ Ն. ԱԴՈՆՑԻ ԱՆՎԱՆ ՊԱՏՄՈՒԹՅԱՆ ԹԱՆԳԱՐԱՆԻ ԱՐՁԱՆԱԳԻՐ ԱՌԱՐԿԱՆԵՐԸ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՎԻՄԱԳՐԱԿԱՆ ՀԻՇԱՏԱԿՈՒԹՅՈՒՆՆԵՐԸ_ՀԱՐՈՒԹՅՈՒՆՅԱՆ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Վիմագրություն. դաս. Ա. Հարությունյան_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Վրաց-պետական-քաղաքականությունը_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՏԱԹԵՎԻ_ՎԱՆՔԻ_ՆՈՐԱՀԱՅՏ_ԾԱԾԿԱԳԻՐԸ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՏԱԹԵՒԻ ՄԵԾ ԱՆԱՊԱՏԻ ՎԻՄԱԳՐԱԿԱՆ  ԺԱՌԱՆԳՈՒԹՅՈՒՆԸ_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՏԱՐԵՐԱՅԻՆ ԱՂԵՏՆԵՐՆ _1_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՏԱՐԵՐԱՅԻՆ ԱՂԵՏՆԵՐՆ _2_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՏԱՐԵՐԱՅԻՆ ԱՂԵՏՆԵՐՆ _3_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/Ցաղաց քար վանք_cleaned.txt
# Cleaned file saved as: C:/Users/Kamal/OneDrive/Desktop/PDS/corpus_txt/cleaned/ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲԱՆԱՆԻ-ՏԱՊԱՆԱԳՐԵՐՈՒՄ_cleaned.txt
#     page                                           sentence       source_file
# 0      1                              Ե 2 - ա -- ---- ----Բ  Divan_Prak10.txt
# 1      1                                                  4  Divan_Prak10.txt
# 2      1                                                  "  Divan_Prak10.txt
# 3      1                                                0 4  Divan_Prak10.txt
# 4      1                                               23 "  Divan_Prak10.txt
# 5      1                                                # 4  Divan_Prak10.txt
# 6      6  ########### ####### ######\n####### ##########...  Divan_Prak10.txt
# 7      6                         #### 3\n######### ########  Divan_Prak10.txt
# 8      6                                            8######  Divan_Prak10.txt
# 9      6                                                  X  Divan_Prak10.txt
# 10     6                                            #B### X  Divan_Prak10.txt
# 11     6            ######\n############ ############\n2017  Divan_Prak10.txt
# 12     7                                             ❇##797  Divan_Prak10.txt
# 13     7                                               2017  Divan_Prak10.txt
# 14     8  Տպագրվում է Հ3 ԳԱՍ հնագիտության և ազգագրության...  Divan_Prak10.txt
# 15     8  Խմբագրական խորհուրդ՝ Գր.Ս. Գրիգորյան, Հ. Ա. Մե...  Divan_Prak10.txt
# 16     8  Պրակը հրատարակության պատրաստեցին՝ պատմ. գիտ. թ...  Divan_Prak10.txt
# 17     8  Պատասխանատու խմբագիրներ՝ Գ. Գ. Սարգսյան, Ա.Է. ...  Divan_Prak10.txt
# 18     8  Դ520 Դիվան հայ վիմագրության. պրակ X, Շիրակի մա...  Divan_Prak10.txt
# 19     8  Պրակն ընդգրկում է ԳՀեիրակի մարզի վիմական արձան...  Divan_Prak10.txt

# %% [markdown]
# # Studying and Filtering

# %%
corpus.head()
corpus.replace('', np.nan, inplace=True)
corpus
# Out:
#         page                                           sentence  \
# 0          1                              Ե 2 - ա -- ---- ----Բ
# 1          1                                                  4
# 2          1                                                  "
# 3          1                                                0 4
# 4          1                                               23 "
# ...      ...                                                ...
# 157324   166                                          վերջերից։
# 157325   166  Պաշտոնապես գրանցվել է Գերմանիայում 1982 թ., իս...
# 157326   166  Նպատակն է իրականացնել ներկայիս Հայաստանի Հանրա...
# 157327   166                             ուսումնասիրություններ։
# 157328   166                                      2015, հայերեն
#
#                                               source_file
# 0                                        Divan_Prak10.txt
# 1                                        Divan_Prak10.txt
# 2                                        Divan_Prak10.txt
# 3                                        Divan_Prak10.txt
# 4                                        Divan_Prak10.txt
# ...                                                   ...
# 157324  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...
# 157325  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...
# 157326  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...
# 157327  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...
# 157328  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...
#
# [157329 rows x 3 columns]

# %% [markdown]
# ## Empty text filtration

# %% [markdown]
# ### **Cleaning is done here**

# %%
corpus.dropna(subset=['sentence'],inplace=True)
corpus['sentence']=corpus['sentence'].apply(lambda x: clean_text(x))
corpus['text_length']=corpus['sentence'].apply(lambda x: len(x.strip().split()))
sns.histplot(corpus[corpus['text_length']<=20]['text_length'],kde=True,bins=20)
plt.xlabel('Number of words in sentence')
plt.ylabel('Frequency')
plt.title('Distribution of Sentence Lengths (up to 20 words)')
# Out:
# Text(0.5, 1.0, 'Distribution of Sentence Lengths (up to 20 words)')

# %%
corpus.head()
# Out:
#    page sentence       source_file  text_length
# 0     1    ե ա բ  Divan_Prak10.txt            3
# 1     1           Divan_Prak10.txt            0
# 2     1           Divan_Prak10.txt            0
# 3     1           Divan_Prak10.txt            0
# 4     1           Divan_Prak10.txt            0

# %%
thresholds = range(0, 11)  
empty_pages_counts = []
cumsums=[]

for t in thresholds:
    count = corpus[corpus['text_length'] == t].shape[0]  
    cumsum= corpus[corpus['text_length'] <= t].shape[0]  
    empty_pages_counts.append(count)
    cumsums.append(cumsum)


df_plot = pd.DataFrame({
    'empty_page_threshold': thresholds,
    'total_empty_pages': empty_pages_counts
})


sns.barplot(x='empty_page_threshold', y='total_empty_pages', data=df_plot)
plt.xlabel("Empty Page Threshold")
plt.ylabel("Total Empty Pages")
plt.title("Distribution of Empty Pages by Threshold of Text Length")
plt.show()

# %%
sns.barplot(x=thresholds, y=[(s/len(corpus))*100 for s in cumsums])
plt.xlabel("Empty Page Threshold")
plt.ylabel("Percentage of Total pages (%)")
plt.title("Distribution of Empty Pages by Threshold of Text Length")
# Out:
# Text(0.5, 1.0, 'Distribution of Empty Pages by Threshold of Text Length')

# %% [markdown]
# Choose 3 as standard emptyness thershold
# ### Thesholding

# %%
empty_pages=corpus[corpus['text_length']<3][['text_length','source_file']].groupby('source_file').count().reset_index().rename(columns={'text_length':'empty_pages'})
corpus=corpus.merge(empty_pages,on='source_file',how='left')
corpus
# Out:
#         page                                           sentence  \
# 0          1                                              ե ա բ
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...                                                ...
# 157324   166                                          վերջերից։
# 157325   166  պաշտոնապես գրանցվել է գերմանիայում թ իսկ հայաս...
# 157326   166  նպատակն է իրականացնել ներկայիս հայաստանի հանրա...
# 157327   166                             ուսումնասիրություններ։
# 157328   166                                            հայերեն
#
#                                               source_file  text_length  \
# 0                                        Divan_Prak10.txt            3
# 1                                        Divan_Prak10.txt            0
# 2                                        Divan_Prak10.txt            0
# 3                                        Divan_Prak10.txt            0
# 4                                        Divan_Prak10.txt            0
# ...                                                   ...          ...
# 157324  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            1
# 157325  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           10
# 157326  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           19
# 157327  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            1
# 157328  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            1
#
#         empty_pages_x  empty_pages_y  empty_pages
# 0                 803            803          803
# 1                 803            803          803
# 2                 803            803          803
# 3                 803            803          803
# 4                 803            803          803
# ...               ...            ...          ...
# 157324            938            938          938
# 157325            938            938          938
# 157326            938            938          938
# 157327            938            938          938
# 157328            938            938          938
#
# [157329 rows x 7 columns]

# %%
sorted_corpus=corpus[['source_file','empty_pages_x']].drop_duplicates().sort_values(by='empty_pages_x',ascending=False)
sns.barplot(x=sorted_corpus['source_file'],y=sorted_corpus['empty_pages_x'])
plt.xticks(rotation=90)
plt.show()

# %%
filtered_corpus=corpus[corpus['text_length']>3]
filtered_corpus
# Out:
#         page                                           sentence  \
# 14         8  տպագրվում է հ գաս հնագիտության և ազգագրության ...
# 15         8  խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...
# 16         8  պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...
# 17         8  պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...
# 18         8  դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...
# ...      ...                                                ...
# 157299   163                    քէլէշեան մ սիս մատեան պէյրութ ։
# 157300   163  ազդակ մայիս ։ ճայիս ։ ապրիլ ։ ազդակ բացառիկ ։ ...
# 157322   166  հայկական ճարտարապետությունն ուսումնասիրող հճու...
# 157325   166  պաշտոնապես գրանցվել է գերմանիայում թ իսկ հայաս...
# 157326   166  նպատակն է իրականացնել ներկայիս հայաստանի հանրա...
#
#                                               source_file  text_length  \
# 14                                       Divan_Prak10.txt           11
# 15                                       Divan_Prak10.txt           11
# 16                                       Divan_Prak10.txt           19
# 17                                       Divan_Prak10.txt            8
# 18                                       Divan_Prak10.txt           35
# ...                                                   ...          ...
# 157299  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            6
# 157300  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           35
# 157322  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            9
# 157325  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           10
# 157326  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           19
#
#         empty_pages_x  empty_pages_y  empty_pages
# 14                803            803          803
# 15                803            803          803
# 16                803            803          803
# 17                803            803          803
# 18                803            803          803
# ...               ...            ...          ...
# 157299            938            938          938
# 157300            938            938          938
# 157322            938            938          938
# 157325            938            938          938
# 157326            938            938          938
#
# [100854 rows x 7 columns]

# %% [markdown]
# ## Short text filtration

# %%
filtered_corpus['max_token_length']=filtered_corpus['sentence'].apply(lambda x: max([len(token) for token in x.split()]))
sns.histplot(filtered_corpus['max_token_length'],kde=True,bins=100)
plt.xlabel('Max Token Length')
plt.title('Distribution of Max Token Lengths in Pages')
plt.axvline(x=5, color='red', linestyle='--', linewidth=2, label='Minimum reference term length')
plt.legend()
plt.show()
# Out:
# C:\Users\Kamal\AppData\Local\Temp\ipykernel_14576\3745239589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_corpus['max_token_length']=filtered_corpus['sentence'].apply(lambda x: max([len(token) for token in x.split()]))

# %%
reference_terms=pd.read_excel('C:/Users/Kamal/OneDrive/Desktop/PDS/Copy of corpus_inscription_terms.xlsx',sheet_name='Terms with Examples')
reference_terms.dropna(subset='term',inplace=True)
reference_terms['term_length']=reference_terms['term'].apply(lambda x: max([len(token) for token in x.split()]))
sns.histplot(reference_terms['term_length'],kde=True,bins=25)
plt.xlabel('Term Length')
plt.title('Distribution of Reference Term Lengths')
# Out:
# Text(0.5, 1.0, 'Distribution of Reference Term Lengths')

# %%
reference_terms.describe()
# Out:
#        count_in_file  term_length
# count     694.000000   694.000000
# mean        1.445245    10.047550
# std         2.535013     3.212402
# min         1.000000     5.000000
# 25%         1.000000     7.000000
# 50%         1.000000     9.000000
# 75%         1.000000    12.000000
# max        49.000000    21.000000

# %% [markdown]
# Given the distribution of the reference terms' lenghts, let's discard of the pages that have a max token length of 3

# %%
filtered_corpus=filtered_corpus[filtered_corpus['max_token_length']>3]
filtered_corpus
# Out:
#         page                                           sentence  \
# 14         8  տպագրվում է հ գաս հնագիտության և ազգագրության ...
# 15         8  խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...
# 16         8  պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...
# 17         8  պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...
# 18         8  դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...
# ...      ...                                                ...
# 157299   163                    քէլէշեան մ սիս մատեան պէյրութ ։
# 157300   163  ազդակ մայիս ։ ճայիս ։ ապրիլ ։ ազդակ բացառիկ ։ ...
# 157322   166  հայկական ճարտարապետությունն ուսումնասիրող հճու...
# 157325   166  պաշտոնապես գրանցվել է գերմանիայում թ իսկ հայաս...
# 157326   166  նպատակն է իրականացնել ներկայիս հայաստանի հանրա...
#
#                                               source_file  text_length  \
# 14                                       Divan_Prak10.txt           11
# 15                                       Divan_Prak10.txt           11
# 16                                       Divan_Prak10.txt           19
# 17                                       Divan_Prak10.txt            8
# 18                                       Divan_Prak10.txt           35
# ...                                                   ...          ...
# 157299  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            6
# 157300  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           35
# 157322  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            9
# 157325  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           10
# 157326  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           19
#
#         empty_pages_x  empty_pages_y  empty_pages  max_token_length
# 14                803            803          803                12
# 15                803            803          803                10
# 16                803            803          803                14
# 17                803            803          803                13
# 18                803            803          803                14
# ...               ...            ...          ...               ...
# 157299            938            938          938                 8
# 157300            938            938          938                11
# 157322            938            938          938                18
# 157325            938            938          938                18
# 157326            938            938          938                14
#
# [99330 rows x 8 columns]

# %%
filtered_corpus[['source_file','page','sentence']].to_json('filtered_corpus.jsonl',orient='records',lines=True,force_ascii=False)

# %%
corpus
# Out:
#         page                                           sentence  \
# 0          1                                              ե ա բ
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...                                                ...
# 157324   166                                          վերջերից։
# 157325   166  պաշտոնապես գրանցվել է գերմանիայում թ իսկ հայաս...
# 157326   166  նպատակն է իրականացնել ներկայիս հայաստանի հանրա...
# 157327   166                             ուսումնասիրություններ։
# 157328   166                                            հայերեն
#
#                                               source_file  text_length  \
# 0                                        Divan_Prak10.txt            3
# 1                                        Divan_Prak10.txt            0
# 2                                        Divan_Prak10.txt            0
# 3                                        Divan_Prak10.txt            0
# 4                                        Divan_Prak10.txt            0
# ...                                                   ...          ...
# 157324  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            1
# 157325  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           10
# 157326  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...           19
# 157327  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            1
# 157328  ՑԵՂԱՍՊԱՆՈՒԹՅՈՒՆԸ-ՎԵՐԱՊՐԱԾՆԵՐԻ-ԾՆՆԴԱՎԱՅՐԵՐԸ-ԼԻԲ...            1
#
#         empty_pages_x  empty_pages_y  empty_pages
# 0                 803            803          803
# 1                 803            803          803
# 2                 803            803          803
# 3                 803            803          803
# 4                 803            803          803
# ...               ...            ...          ...
# 157324            938            938          938
# 157325            938            938          938
# 157326            938            938          938
# 157327            938            938          938
# 157328            938            938          938
#
# [157329 rows x 7 columns]

# %% [markdown]
# ## Analysis of manual extractions

# %%
reference_terms=pd.read_excel('C:/Users/Kamal/OneDrive/Desktop/PDS/Copy of corpus_inscription_terms.xlsx',sheet_name='Terms with Examples')
reference_terms.dropna(subset=['term'],inplace=True) 
reference_terms.drop_duplicates(subset=['term','example'],inplace=True)
reference_terms['term']=reference_terms['term'].apply(lambda x: clean_text(x))
reference_terms.head()
# Out:
#                                              term  \
# 0                                       տապանագիր
# 2                                         սեպագիր
# 3       ալս գլուղում պահպանվել են արձանագրություն
# 4  ալս մատուռի մեջ անցլալում եղել են չորս ձեռագիր
# 5                                 ամփոփ տեղեկագիր
#
#                              file  count_in_file  \
# 0                Divan_Prak10.txt              2
# 2                 Divan_Prak4.txt              1
# 3                 Divan_Prak3.txt              1
# 4                 Divan_Prak5.txt              1
# 5  ՀԱԼԵՊԻ-ԱՐՁԱՆԱԳՐՈՒԹՅՈՒՆՆԵՐԸ.txt              2
#
#                                              example
# 0  նք, գերեզմանոց -  Լմբատավանք, գերեզմանոց տապան...
# 2  ն րերդշեն, որը գրավել է ուրարտական Ռուսա թագավ...
# 3   ԵՒ ՈՎՍԵՓԱ. ԹՎ. 2։ (1251) Ծանոթ. Գծագիրն ստացե...
# 4  զրին. փոք- րիկ մատուռ է, որի բեմի տակ դամբարան...
# 5  ., նշվ. աշխ., էջ 310։  113 Գապպէնճեան Գ., նշվ....

# %%
sns.histplot(x=reference_terms['term'].drop_duplicates().apply(lambda x: len(x.split())))
# Out:
# <Axes: xlabel='term', ylabel='Count'>

# %%
unique_terms=pd.read_excel('C:/Users/Kamal/OneDrive/Desktop/PDS/Copy of corpus_inscription_terms.xlsx',sheet_name='Unique Terms')
unique_terms.drop(columns=['Unnamed: 2'],inplace=True)
unique_terms.dropna(inplace=True)
unique_terms
# Out:
#                   term  total_count
# 0    հիշատակագրություն           83
# 1            արձանագիր           35
# 2          հիշատակագիր           30
# 3      արձանագրություն           26
# 4              ձեռագիր           26
# ..                 ...          ...
# 552           խնդրագիր            1
# 555         վայելչագիր            1
# 556      բառ պատուագիր            1
# 567             ապագիր            1
# 568    թվագիր ծածկագիր            1
#
# [175 rows x 2 columns]

# %%
sns.histplot(x=unique_terms['term'].drop_duplicates().apply(lambda x: len(x.split())))
# Out:
# <Axes: xlabel='term', ylabel='Count'>

# %%
from matplotlib_venn import venn2
set_ref=set(reference_terms['term'])
set_unique=set(unique_terms['term'])
venn2([set_ref, set_unique], set_labels=("Reference Terms", "Unique Terms"))

# %% [markdown]
# ## Preparation for Divan Prak 10 case study
#
# Extraction is done on ***OpenAI Prototype*** notebook

# %%
divan10=pd.read_json('filtered_corpus.jsonl',lines=True)
divan10=divan10[divan10['source_file']=='Divan_Prak10.txt']
divan10['page_number']=divan10['page']
divan10['cleaned_text']=divan10['sentence']
divan10.drop(columns=['page','sentence'],inplace=True)
divan10.head()
# Out:
#         source_file  page_number  \
# 0  Divan_Prak10.txt            8
# 1  Divan_Prak10.txt            8
# 2  Divan_Prak10.txt            8
# 3  Divan_Prak10.txt            8
# 4  Divan_Prak10.txt            8
#
#                                         cleaned_text
# 0  տպագրվում է հ գաս հնագիտության և ազգագրության ...
# 1  խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...
# 2  պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...
# 3  պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...
# 4  դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...

# %%
len(divan10)
# Out:
# 1638

# %%
import os
import json
import pandas as pd

def load_extractions_from_dir(directory: str) -> pd.DataFrame:
    records = []

    for file in os.listdir(directory):
        if file.endswith(".json"):  # only JSON files
            filepath = os.path.join(directory, file)

            with open(filepath, "r", encoding="utf-8") as f:
                data = json.load(f)  # load full JSON

            # walk through terms → extractions
            for term_entry in data.get("terms", []):
                for occ in term_entry.get("extractions", []):
                    records.append({
                        "dict_term": term_entry.get("term"),
                        "definition": term_entry.get("definition"),
                        "term": occ.get("term"),
                        "context": occ.get("context"),
                        "file_name": occ.get("file_name"),
                        "page_number": occ.get("page_number"),
                        "source_file": file,
                    })

    return pd.DataFrame(records)

# Example usage
divan10_extractions = load_extractions_from_dir("C:/Users/Kamal/OneDrive/Documents/GitHub/dhlab-epigraphy-studies/preprocessing/divan10")
divan10_extractions.drop(columns=["dict_term", "definition"], inplace=True)
divan10_extractions.head()
# Out:
#         term                                            context     file_name  \
# 0    վիմագիր  արևելյան նիրակի ներկայիս ... շիրակի մարզ վիմագ...  Divan_Prak10
# 1  վիմագրերը  թվային ծոտոխցիկներով լուսանկարել պրակում լուսա...  Divan_Prak10
# 2  վիմագրերը  տեղում համեմատել վիմագրերը։ 2 ձեռքի տակ ունենա...  Divan_Prak10
# 3  վիմագրերը  եթե խաչի ձորի վիմագրերը թե րևս չէին կարող լինե...  Divan_Prak10
# 4  վիմագրերի  վիմագրերի վերծանության գրեթե հիսնամյա հեռավորո...  Divan_Prak10
#
#    page_number              source_file
# 0           11  extraction_chunk_1.json
# 1           12  extraction_chunk_1.json
# 2           12  extraction_chunk_1.json
# 3           12  extraction_chunk_1.json
# 4           11  extraction_chunk_1.json

# %% [markdown]
# ## Term distribution

# %% [markdown]
# ### Special Terms Per Page

# %%
occurences_per_page=divan10_extractions[['page_number','term']].groupby('page_number').count().reset_index().sort_values(by='term',ascending=False)
plt.figure(figsize=(20, 6))
sns.barplot(x=occurences_per_page['page_number'], y=occurences_per_page['term'],order=occurences_per_page["page_number"])
plt.xlabel('Page Number')
plt.ylabel('Number of Terms Extracted')
plt.xticks(rotation=90)
plt.title('Distribution of Extracted Terms per Page in Divan 10')
plt.show()

# %% [markdown]
# #### Proportion of Sentece of Interest per page

# %%
divan10_extractions['context_legth']=divan10_extractions['context'].apply(lambda x: len(x.split()))
interest_per_page=divan10_extractions[['page_number','context_legth']].groupby('page_number').sum().reset_index()



divan10['text_length']=divan10['cleaned_text'].apply(lambda x: len(x.split()))
tokens_per_page=divan10[['page_number','text_length']].groupby('page_number').sum().reset_index()


ratios=pd.merge(interest_per_page,tokens_per_page,on='page_number',how='outer')
ratios['ratio']=(ratios['context_legth']/(ratios['text_length'].sum()))*100
ratios['ratio'].fillna(0,inplace=True)
ratios.sort_values(by='ratio',ascending=False,inplace=True)


plt.figure(figsize=(20, 6))
sns.barplot(x=ratios['page_number'],y=ratios['ratio'],order=ratios['page_number'])
plt.xlabel('Page Number')
plt.xticks(rotation=90)
plt.ylabel('Proportion of Terms of Interest (%)')
plt.title('Proportion of Terms of Interest per Page in Divan 10')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Kamal\AppData\Local\Temp\ipykernel_26416\3249919368.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ratios['ratio'].fillna(0,inplace=True)

# %% [markdown]
# # Conversion to Trainable Data

# %%
df=pd.merge(divan10[['page_number','cleaned_text']],divan10_extractions[['page_number','term','context']],on='page_number',how='outer')
df.head()
# Out:
#    page_number                                       cleaned_text  \
# 0            8  տպագրվում է հ գաս հնագիտության և ազգագրության ...
# 1            8  խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...
# 2            8  պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...
# 3            8  պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...
# 4            8  դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...
#
#                           term  \
# 0  վիմական արձանագրությունները
# 1  վիմական արձանագրությունները
# 2  վիմական արձանագրությունները
# 3  վիմական արձանագրությունները
# 4  վիմական արձանագրությունները
#
#                                              context
# 0  պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...
# 1  պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...
# 2  պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...
# 3  պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...
# 4  պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...

# %%
import pandas as pd
import re
import json
import math

def split_arm_sentence(text):
    """
    Splits a paragraph into sentences using only Armenian full stop (։)
    """
    # Replace line breaks with spaces
    text = text.replace("\n", " ").replace("\r", " ")
    
    # Split by Armenian full stop
    sentences = [s.strip() for s in text.split('։') if s.strip()]
    
    return sentences

dataset = []

for _, row in df.iterrows():
    text = str(row['cleaned_text'])
    sentences = split_arm_sentence(text)
    
    term = row['term']
    context = row['context']
    page_number = row['page_number']

    for sentence in sentences:
        input_text = sentence
        output_entities = []

        if term is not None and not (isinstance(term, float) and math.isnan(term)):
            # Annotate if term or context appears in the sentence
            if str(term) in sentence or (context is not None and str(context) in sentence):
                output_entities.append(f"{term}: type of inscription")

        output_text = ", ".join(output_entities) if output_entities else ""
        dataset.append({"input": input_text, "output": output_text, "page_number": page_number})

# Save to JSONL
with open("divan10_data.jsonl", "w", encoding="utf-8") as f:
    for entry in dataset:
        f.write(json.dumps(entry, ensure_ascii=False) + "\n")

print(f"Dataset created! Total rows: {len(dataset)}")
# Out:
# Dataset created! Total rows: 2747

# %%
ner_data=pd.read_json('divan10_data.jsonl',lines=True)
ner_data.drop_duplicates(inplace=True)
ner_data.head()
# Out:
#                                                input output  page_number
# 0  տպագրվում է հ գաս հնագիտության և ազգագրության ...                   8
# 1  խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...                   8
# 2  պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...                   8
# 3  պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...                   8
# 4  դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...                   8

# %% [markdown]
# ## NER Dataset EDA

# %% [markdown]
# ### Sentece lengths

# %%
ner_data['input_length']=ner_data['input'].apply(lambda x: len(x.split()))
sns.histplot(ner_data[ner_data['input_length']<=20]['input_length'],kde=True,bins=20)
plt.title('Distribution of Input Sentence Lengths (<=20 tokens)')
# Out:
# Text(0.5, 1.0, 'Distribution of Input Sentence Lengths (<=20 tokens)')

# %% [markdown]
# Given armenian language, sentences can be two tokens long. We'll remove all sentences that are less than two tokens long

# %%
ner_data=ner_data[ner_data['input_length']>2]

# %% [markdown]
# ### Numeric proportion

# %%
import re

def numeric_token_proportion(sentence):
    """
    Calculates the proportion of numerical tokens in a sentence.
    
    Args:
        sentence (str): Input sentence.
    
    Returns:
        float: Proportion of numeric tokens (0 to 1).
    """
    # Split sentence into tokens (words) by whitespace
    tokens = sentence.split()
    
    if not tokens:
        return 0.0  # avoid division by zero for empty sentence
    
    # Count tokens that are numbers (integers or decimals)
    numeric_count = sum(1 for token in tokens if re.fullmatch(r'\d+(\.\d+)?', token))
    
    proportion = numeric_count / len(tokens)
    return proportion

# %%
ner_data['numeric_proportion']=ner_data['input'].apply(numeric_token_proportion)
sns.histplot(ner_data['numeric_proportion'],kde=True,bins=20)
plt.title('Distribution of Numeric Token Proportions in Sentences')
# Out:
# Text(0.5, 1.0, 'Distribution of Numeric Token Proportions in Sentences')

# %%
filtered_ner_data = ner_data[
    ~(
        (ner_data['output'] == "") & 
        (ner_data['numeric_proportion'] > 0.3)
    )
].reset_index(drop=True)

print(f"Filtered dataset size: {len(filtered_ner_data)}")
# Out:
# Filtered dataset size: 1804

# %%
filtered_ner_data
# Out:
#                                                   input output  page_number  \
# 0     տպագրվում է հ գաս հնագիտության և ազգագրության ...                   8
# 1     խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...                   8
# 2     պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...                   8
# 3     պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...                   8
# 4     դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...                   8
# ...                                                 ...    ...          ...
# 1799            անասուն եզի գութանի սարւած կով ձի ոչխար                 214
# 1800  սպասք իրեր ձեռագրեր անձինք արծաթեղէն աւետարան ...                 214
# 1801  անասուն արդիւնք բաժին հոգո ընծա իրեր կիրսն հալ...                 214
# 1802       էջադրումը և ձևավորումը արթուր հարությունյանի                 216
# 1803              տպագրված է հայկարլի սպը տպարանում հեռ                 216
#
#       input_length  numeric_proportion
# 0               11                 0.0
# 1               11                 0.0
# 2               19                 0.0
# 3                8                 0.0
# 4               35                 0.0
# ...            ...                 ...
# 1799             7                 0.0
# 1800            23                 0.0
# 1801            11                 0.0
# 1802             5                 0.0
# 1803             6                 0.0
#
# [1804 rows x 5 columns]

# %% [markdown]
# ## Armenian Fraction

# %%
def armenian_fraction(text):
    tokens = text.split()
    if not tokens:
        return 0
    return sum(1 for t in tokens if re.search(r'[\u0530-\u058F]', t)) / len(tokens)

filtered_ner_data['armenian_fraction'] = filtered_ner_data['input'].apply(armenian_fraction)
sns.histplot(filtered_ner_data['armenian_fraction'],kde=True,bins=20)
plt.title('Distribution of Armenian Token Proportions in Sentences')
# Out:
# Text(0.5, 1.0, 'Distribution of Armenian Token Proportions in Sentences')

# %%
filtered_ner_data = filtered_ner_data[
    ~(
        (filtered_ner_data['output'] == "") & 
        (filtered_ner_data['armenian_fraction'] <0.60)
    )
].reset_index(drop=True)

filtered_ner_data.count()
# Out:
# input                 1804
# output                1804
# page_number           1804
# input_length          1804
# numeric_proportion    1804
# armenian_fraction     1804
# dtype: int64

# %%
filtered_ner_data
# Out:
#                                                   input output  page_number  \
# 0     տպագրվում է հ գաս հնագիտության և ազգագրության ...                   8
# 1     խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...                   8
# 2     պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...                   8
# 3     պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...                   8
# 4     դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...                   8
# ...                                                 ...    ...          ...
# 1799            անասուն եզի գութանի սարւած կով ձի ոչխար                 214
# 1800  սպասք իրեր ձեռագրեր անձինք արծաթեղէն աւետարան ...                 214
# 1801  անասուն արդիւնք բաժին հոգո ընծա իրեր կիրսն հալ...                 214
# 1802       էջադրումը և ձևավորումը արթուր հարությունյանի                 216
# 1803              տպագրված է հայկարլի սպը տպարանում հեռ                 216
#
#       input_length  numeric_proportion  armenian_fraction
# 0               11                 0.0                1.0
# 1               11                 0.0                1.0
# 2               19                 0.0                1.0
# 3                8                 0.0                1.0
# 4               35                 0.0                1.0
# ...            ...                 ...                ...
# 1799             7                 0.0                1.0
# 1800            23                 0.0                1.0
# 1801            11                 0.0                1.0
# 1802             5                 0.0                1.0
# 1803             6                 0.0                1.0
#
# [1804 rows x 6 columns]

# %% [markdown]
# ### Duplicate Drop

# %%
filtered_ner_data=filtered_ner_data[['input','output']]
filtered_ner_data = filtered_ner_data.sort_values(by="output", ascending=False, key=lambda col: col != "")
filtered_ner_data
# Out:
#                                                   input  \
# 484   գիմք ընդունելով ձեռագրում տվյալ միավորի խորագի...
# 978   նախորդ հրատարակիչը վիմագրի ծանոթագրության մեջ ...
# 527   ոմն առյուծի հայր սխիթար ճոն հիշատակված է նաև ա...
# 5     պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...
# 33    արևելյան նիրակի ներկայիս հ շիրակի մարզ վիմագիր...
# ...                                                 ...
# 1713                գրրածա ուրարտական պետության կացձում
# 1714  թագավորական կամուրջ բանդիվան գյուղում թալին թա...
# 1715  թաղք գյուղ արթիկի մերծակայքում որը նվիրաբերվել...
# 1716  իլխինապ իլխիաբ իլխիաբի գյուղ ալեքսանդրապոլի գա...
# 1803              տպագրված է հայկարլի սպը տպարանում հեռ
#
#                                                 output
# 484                     վիմագրերը: type of inscription
# 978                       Վիմագիր: type of inscription
# 527                    վիմագրերից: type of inscription
# 5     վիմական արձանագրությունները: type of inscription
# 33                        վիմագիր: type of inscription
# ...                                                ...
# 1713
# 1714
# 1715
# 1716
# 1803
#
# [1804 rows x 2 columns]

# %%
filtered_ner_data.drop_duplicates(subset=["input"], keep="first").reset_index(drop=True)
# Out:
#                                                   input  \
# 0     գիմք ընդունելով ձեռագրում տվյալ միավորի խորագի...
# 1     նախորդ հրատարակիչը վիմագրի ծանոթագրության մեջ ...
# 2     ոմն առյուծի հայր սխիթար ճոն հիշատակված է նաև ա...
# 3     պրակն ընդգրկում է գհեիրակի մարզի վիմական արձան...
# 4     արևելյան նիրակի ներկայիս հ շիրակի մարզ վիմագիր...
# ...                                                 ...
# 1725                գրրածա ուրարտական պետության կացձում
# 1726  թագավորական կամուրջ բանդիվան գյուղում թալին թա...
# 1727  թաղք գյուղ արթիկի մերծակայքում որը նվիրաբերվել...
# 1728  իլխինապ իլխիաբ իլխիաբի գյուղ ալեքսանդրապոլի գա...
# 1729              տպագրված է հայկարլի սպը տպարանում հեռ
#
#                                                 output
# 0                       վիմագրերը: type of inscription
# 1                         Վիմագիր: type of inscription
# 2                      վիմագրերից: type of inscription
# 3     վիմական արձանագրությունները: type of inscription
# 4                         վիմագիր: type of inscription
# ...                                                ...
# 1725
# 1726
# 1727
# 1728
# 1729
#
# [1730 rows x 2 columns]

# %%
filtered_ner_data.to_json('divan10_final_data.jsonl',orient='records',lines=True,force_ascii=False)

# %% [markdown]
# ### OCR Failsafe

# %%
import regex

# Armenian Unicode regex
ARMENIAN_RE = regex.compile(r'[\p{IsArmenian}\p{N}\p{P}]+')


def has_numbers(word: str) -> bool:
    """Check if word contains numbers."""
    return bool(re.search(r'\d', word))

def has_three_repeats(word: str) -> bool:
    """Check if word has ≥3 same Armenian characters in a row."""
    return bool(re.search(r'([\u0530-\u058F])\1{2,}', word))

def has_many_doubles(word: str) -> bool:
    """Check if word has ≥3 double Armenian characters (AA, BB, CC)."""
    doubles = re.findall(r'([\u0530-\u058F])\1', word)
    return len(doubles) >= 3

def has_too_many_non_armenian(word: str) -> bool:
    """Check if word has too many non-Armenian characters."""
    armenian_chars = len(ARMENIAN_RE.findall(word))
    return armenian_chars < len(word) / 2

def has_alternating_pattern(word: str) -> bool:
    """Check if word follows repeating 2-letter Armenian pattern."""
    return bool(re.fullmatch(r'(([\u0530-\u058F]{2})){3,}', word))

def is_suspiciously_short(word: str) -> bool:
    """Check if word is suspiciously short and not valid Armenian."""
    return len(word) <= 2 and not re.fullmatch(r'[\u0530-\u058F]+', word)

def OCR_falacies(word: str) -> bool:
    """
    Detects gibberish Armenian terms based on several heuristic rules.
    """
    checks = [
        has_numbers,
        has_three_repeats,
        has_many_doubles,
        has_too_many_non_armenian,
        has_alternating_pattern,
        is_suspiciously_short,
    ]
    
    return any(check(word) for check in checks)

# %%
FALLACY_CHECKS = {
    "has_three_repeats": has_three_repeats,
    "has_many_doubles": has_many_doubles,
    "has_too_many_non_armenian": has_too_many_non_armenian,
}
def gibberish_fractions(sentence: str) -> dict:
    """
    Computes the fraction of each fallacy type across words in a sentence.
    Returns dict: {fallacy_name: fraction, ..., "overall": fraction}
    """
    # Split into words (keep only alphanumeric + Armenian characters)
    words = re.findall(r'[\u0530-\u058F\dA-Za-z]+', sentence)

    if not words:
        return {name: 0.0 for name in FALLACY_CHECKS} | {"overall": 0.0}

    # Count per fallacy
    results = {name: 0 for name in FALLACY_CHECKS}
    total_words = len(words)

    for w in words:
        for name, fn in FALLACY_CHECKS.items():
            if fn(w):
                results[name] += 1

    # Convert to fractions
    fractions = {name: count / total_words for name, count in results.items()}

    # Overall gibberish = fraction of words flagged by at least one fallacy
    gibberish_count = sum(
        any(fn(w) for fn in FALLACY_CHECKS.values()) for w in words
    )
    fractions["overall"] = gibberish_count / total_words

    return fractions

# %%
fractions_df = filtered_ner_data['input'].apply(gibberish_fractions).apply(pd.Series)
fractions_df.head()
# Out:
#    has_three_repeats  has_many_doubles  has_too_many_non_armenian   overall
# 0                0.0               0.0                   0.727273  0.727273
# 1                0.0               0.0                   0.454545  0.454545
# 2                0.0               0.0                   0.684211  0.684211
# 3                0.0               0.0                   0.500000  0.500000
# 4                0.0               0.0                   0.571429  0.571429

# %%
new_ner=filtered_ner_data.copy()
new_ner = new_ner.join(fractions_df)
new_ner['is_empty'] = new_ner['output'].eq("")
melted = new_ner.melt(
    id_vars=['input', 'is_empty'],
    value_vars=list(fractions_df.columns),  # all fallacy metrics
    var_name="metric",
    value_name="fraction"
)

# Plot histograms by metric, with hue on is_empty
g = sns.FacetGrid(melted, col="metric", col_wrap=2, sharex=False, sharey=False, height=3.5,hue='is_empty')
g.map_dataframe(sns.histplot, x="fraction", element="step", multiple="layer",stat="count",alpha=0.5, common_norm=False)
g.add_legend()

plt.subplots_adjust(top=0.9)
g.fig.suptitle("Histogram of Gibberish Fractions by Metric ")
plt.show()

# %% [markdown]
# ### Cleaning larger Chunks

# %%
sns.histplot(filtered_ner_data[filtered_ner_data['input_length']>100]['input_length'],kde=True,bins=20)
# Out:
# <Axes: >

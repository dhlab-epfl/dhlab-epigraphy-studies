# %%
import pandas as pd
import numpy as np
import openai
import re
import os
import glob
import json
import seaborn as sns
import matplotlib.pyplot as plt
from loading_helpers import *

# %%
openai.api_key=os.environ['OPENAI_API_KEY']

# %%
df=pd.read_json('C:/Users/Kamal/OneDrive/Documents/GitHub/dhlab-epigraphy-studies/preprocessing/Text Cleaning/filtered_corpus.jsonl', lines=True)

# %%
df.head()
# Out:
#         source_file  page                                           sentence
# 0  Divan_Prak10.txt     8  տպագրվում է հ գաս հնագիտության և ազգագրության ...
# 1  Divan_Prak10.txt     8  խմբագրական խորհուրդ՝ գր ս գրիգորյան հ ա մելքոն...
# 2  Divan_Prak10.txt     8  պրակը հրատարակության պատրաստեցին՝ պատմ գիտ թեկ...
# 3  Divan_Prak10.txt     8  պատասխանատու խմբագիրներ՝ գ գ սարգսյան ա է հարո...
# 4  Divan_Prak10.txt     8  դ դիվան հայ վիմագրության պրակ շիրակի մարզ կազմ...

# %%
reference_terms=pd.read_excel('C:/Users/Kamal/OneDrive/Desktop/PDS/Copy of corpus_inscription_terms.xlsx',sheet_name='Terms with Examples')
reference_terms.dropna(subset=['term'],inplace=True) 
reference_terms.drop_duplicates(subset=['term','example'],inplace=True)
reference_terms['term']=reference_terms['term'].apply(lambda x: clean_text(x))
reference_terms
# Out:
#                                                term  \
# 0                                         տապանագիր
# 2                                           սեպագիր
# 3         ալս գլուղում պահպանվել են արձանագրություն
# 4    ալս մատուռի մեջ անցլալում եղել են չորս ձեռագիր
# 5                                   ամփոփ տեղեկագիր
# ..                                              ...
# 690                              քարերն անարձանագիր
# 691                                      քարտեզագիր
# 692       օգտվել է յոհան ոսկերչյան քահանայի ծեռագիր
# 693                                          օրագիր
# 694                       օրոք կանգնեցված արձանագիր
#
#                                              file  count_in_file  \
# 0                                Divan_Prak10.txt              2
# 2                                 Divan_Prak4.txt              1
# 3                                 Divan_Prak3.txt              1
# 4                                 Divan_Prak5.txt              1
# 5                  ՀԱԼԵՊԻ-ԱՐՁԱՆԱԳՐՈՒԹՅՈՒՆՆԵՐԸ.txt              2
# ..                                            ...            ...
# 690                             Բուն-Աղվանք-1.txt              1
# 691                                  Խոջիվանք.txt              1
# 692                               Divan_Prak9.txt              1
# 693                              Divan_Prak10.txt              1
# 694  ԱՐՑԱԽԻ-ԵՎ-ՍՅՈՒՆԻՔԻ-ՄԵԼԻՔԱԿԱՆ-ԱՊԱՐԱՆՔՆԵՐԸ.txt              1
#
#                                                example
# 0    նք, գերեզմանոց -  Լմբատավանք, գերեզմանոց տապան...
# 2    ն րերդշեն, որը գրավել է ուրարտական Ռուսա թագավ...
# 3     ԵՒ ՈՎՍԵՓԱ. ԹՎ. 2։ (1251) Ծանոթ. Գծագիրն ստացե...
# 4    զրին. փոք- րիկ մատուռ է, որի բեմի տակ դամբարան...
# 5    ., նշվ. աշխ., էջ 310։  113 Գապպէնճեան Գ., նշվ....
# ..                                                 ...
# 690  5, ծ. մ. 759 #)։ Բնիկ հայերից ավանդված ուղղակյ...
# 691  թ.  Բագարով Սիրան, վխճ. 1926 թ. 167  Բագրատիոն...
# 692  իր պատ- վանդանին։ Սեջտեղի կոտրված մասի մեկ տող...
# 693  րսի» 3. եղիազարյան - «զիս զինչ թը սմայ ունէի տ...
# 694  յկազյան տոհմի մի քանի երևելի ներկայացու- ցիչնե...
#
# [694 rows x 4 columns]

# %%
unique_terms=pd.read_excel('C:/Users/Kamal/OneDrive/Desktop/PDS/Copy of corpus_inscription_terms.xlsx',sheet_name='Unique Terms')
unique_terms.drop(columns=['Unnamed: 2'],inplace=True)
unique_terms.dropna(inplace=True)
unique_terms
# Out:
#                   term  total_count
# 0    հիշատակագրություն           83
# 1            արձանագիր           35
# 2          հիշատակագիր           30
# 3      արձանագրություն           26
# 4              ձեռագիր           26
# ..                 ...          ...
# 552           խնդրագիր            1
# 555         վայելչագիր            1
# 556      բառ պատուագիր            1
# 567             ապագիր            1
# 568    թվագիր ծածկագիր            1
#
# [175 rows x 2 columns]

# %%
one_gram_terms=reference_terms[reference_terms['term'].apply(lambda x: len(x.split()) ==1)]
one_gram_terms=one_gram_terms.groupby('term').agg(list)
one_gram_terms
# Out:
#                                                             file  \
# term
# աեղագիր                                        [Divan_Prak4.txt]
# ազգագրություն     [ԱՐՑԱԽԻ-ԵՎ-ՍՅՈՒՆԻՔԻ-ՄԵԼԻՔԱԿԱՆ-ԱՊԱՐԱՆՔՆԵՐԸ.txt]
# ամսագիր                     [Divan_Prak7.txt, Բուն-Աղվանք-1.txt]
# անարձանագիր    [Divan_Prak3.txt, Divan_Prak4.txt, Divan_Prak5...
# անստորագիր                      [ՀԱԼԵՊԻ-ԱՐՁԱՆԱԳՐՈՒԹՅՈՒՆՆԵՐԸ.txt]
# ...                                                          ...
# փորագիր        [Divan_Prak4.txt, Divan_Prak9.txt, ՀԱԼԵՊԻ-ԱՐՁԱ...
# քարտեզագիր                                        [Խոջիվանք.txt]
# օրագիր                                        [Divan_Prak10.txt]
# ֆափագրություն     [ԱՐՑԱԽԻ-ԵՎ-ՍՅՈՒՆԻՔԻ-ՄԵԼԻՔԱԿԱՆ-ԱՊԱՐԱՆՔՆԵՐԸ.txt]
# ֆփագրություն      [ԱՐՑԱԽԻ-ԵՎ-ՍՅՈՒՆԻՔԻ-ՄԵԼԻՔԱԿԱՆ-ԱՊԱՐԱՆՔՆԵՐԸ.txt]
#
#               count_in_file                                            example
# term
# աեղագիր                 [1]  [ՅՈԱՂՐԱՆ (ՀՆՈՒՍ՝ ՓԱՌԱԿԱՆՔ)  Այո գյաղի անունը մ...
# ազգագրություն           [2]  [յանների համահայկական իշխանա-  Տե՛ս Ստ. Լիսիցյ...
# ամսագիր              [1, 4]  [րում է Նախիջևան Բեսարարիայի հայոց թեմը. մտրգ,...
# անարձանագիր    [1, 2, 2, 5]  [կրորդ եկեղեցին կից է ո. Հովհանեսին հլուսիսից....
# անստորագիր              [1]  [նքի մատնուիլ..., ըսաւ ինծի ոստիկան մը.... սպա...
# ...                     ...                                                ...
# փորագիր        [1, 6, 1, 2]  [երս նայող թեք շրջանակներին մեկ տող ուռուցիկ և...
# քարտեզագիր              [1]  [թ.  Բագարով Սիրան, վխճ. 1926 թ. 167  Բագրատիո...
# օրագիր                  [1]  [րսի» 3. եղիազարյան - «զիս զինչ թը սմայ ունէի ...
# ֆափագրություն           [1]  [ն ապարանքները  Լ1  1Կ45  4 4  ԿՏՐՎԼՍԲ  Կ3ՐՎԼՈ...
# ֆփագրություն            [1]  [ 70։   --- Page 111 ---  777  ՏԵՂ  4և  141413...
#
# [95 rows x 3 columns]

# %% [markdown]
# ### Defining new dataframe for type of inscription

# %%
types_of_inscriptions=pd.read_csv('C:/Users/Kamal/OneDrive/Desktop/PDS/types_of_inscriptions.csv')
types_of_inscriptions.head()
# Out:
#                             Term  \
# 0                        Վիմագիր
# 1        վիմական արձանագրություն
# 2                      Տապանագիր
# 3  տապանաքարային արձանագրություն
# 4          տապանաքարային վիմագիր
#
#                                           Definition
# 0  Ընդհանուր տերմին բոլոր քարե արձանագրություններ...
# 1  Ընդհանուր տերմին բոլոր քարե արձանագրություններ...
# 2  Գերեզմանային արձանագրություն (գերեզմանոցներում...
# 3  Գերեզմանային արձանագրություն (գերեզմանոցներում...
# 4  Գերեզմանային արձանագրություն (գերեզմանոցներում...

# %%
from matplotlib_venn import venn3
set_ref=set(reference_terms['term'])
set_unique=set(unique_terms['term'])
set_inscriptions=set(types_of_inscriptions['Term'].apply(lambda x: clean_text(x)))
venn3([set_ref, set_unique,set_inscriptions], set_labels=("Reference Terms", "Unique Terms","Inscription Types"))

# %% [markdown]
# ## Strategy
# Start out with the inscribtion since definition recorded, then move on to different sets if needed.

# %% [markdown]
# ## Pydantic Scheme
#
# First directed output method lies in directing the model to find occurences of a certain term in chunks of the text.

# %%
from pydantic import BaseModel,Field
from typing import Optional,List


class Occurence(BaseModel):
    file_name: str = Field(None, description="Name of the file where the term was found")
    page_number: int= Field(None, description="Number of the page where the term was found")
    term: str= Field(None, description="Term found in the document")
    context: str= Field(None, description="Context around the term found in the document")

class Term(BaseModel):
    term: str = Field(None, description="The term to be extracted")
    definition: str = Field(None, description="The definition of the term")
    extractions: Optional[List[Occurence]] = Field(default_factory=list, description="List of extractions")


class ExtractionResult(BaseModel):
    terms: List[Term]


terms_list = types_of_inscriptions.to_dict(orient="records")

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ## Prompt Engineering
#
# For now zero, one ,few shot. Then test out CoT prompting,

# %% [markdown]
# ### Chunking tool

# %%
def chunk_jsonl_for_model(file_path: str, max_chars: int = 5000):
    """
    Reads a JSONL file with keys (file_name, page_number, cleaned_text)
    and yields chunks of formatted text under max_chars length.

    Args:
        file_path (str): Path to the JSONL file
        max_chars (int): Maximum number of characters per chunk

    Yields:
        str: Chunk of text ready to send to the model
    """
    buffer = ""
    
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            record = json.loads(line)
            formatted = (
                f"--- File_name: {record['file_name']} , Page_number: {record['page']} ---\n"
                f"{record['sentence']}\n\n"
            )
            
            # If adding this line would exceed max_chars, yield buffer and reset
            if len(buffer) + len(formatted) > max_chars and buffer:
                yield buffer.strip()
                buffer = ""
            
            buffer += formatted
        
        # Yield remaining buffer if not empty
        if buffer.strip():
            yield buffer.strip()

# %%
from typing import Generator
import tiktoken

def chunk_jsonl_for_openai(file_path: str, max_tokens: int = 2000, model: str = "gpt-4"):
    """
    Reads a JSONL file and yields chunks formatted for OpenAI API.
    Each chunk is under max_tokens for the given model.
    
    Args:
        file_path (str): path to JSONL file
        max_tokens (int): max tokens per chunk
        model (str): OpenAI model name for token encoding
        
    Yields:
        str: chunk of text ready for model input
    """
    # Initialize tokenizer
    enc = tiktoken.get_encoding("cl100k_base")
    buffer = ""
    buffer_tokens = 0
    
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            record = json.loads(line)
            formatted = (
                f"--- File_name: {record['source_file']} , Page_number: {record['page']} ---\n"
                f"{record['sentence']}\n\n"
            )
            line_tokens = len(enc.encode(formatted))
            
            # If adding this line exceeds max_tokens, yield buffer and reset
            if buffer_tokens + line_tokens > max_tokens and buffer:
                yield buffer.strip()
                buffer = ""
                buffer_tokens = 0
            
            buffer += formatted
            buffer_tokens += line_tokens
        
        if buffer.strip():
            yield buffer.strip()

# %%
def zero_shot_prompting(chunk,terms):

    zero_shot_prompt=f"""You are an expert in armenian epigraphy. 
    Your task is to extract specific terms from the provided text chunks. 
    For each term, you will identify its occurrences in the text, along with the context in which it appears. 
    The context should include a few words before and after the term to provide clarity on its usage.

    Each occurrence should be documented with the following details:
    - file_name: The name of the file where the term was found.
    - page_number: The page number in the document where the term was found.
    - term: The term itself.
    - context: A snippet of text surrounding the term to provide context.

    Each term can have multiple occurrences, and each occurrence should be recorded separately and stored in an Occurence object.
    All occurrences of a term should be grouped under a Term object, which includes the term, its definition, and a list of its occurrences.

    Finally, all Term objects should be compiled into an ExtractionResult object.

    The text is written in armenian which might be more tedious to handle than engilsh text.
    Extract all occurrences of the following terms from the document text.
    Terms and definitions: {terms}
    
    --- BEGIN TEXT CHUNK ---
    {chunk}
    --- END TEXT CHUNK ---
    """

    return zero_shot_prompt

# %%
from pathlib import Path
from tqdm import tqdm
def extract_terms_and_save(jsonl_file: str, output_dir: str, terms_list: list, max_tokens: int = 20000, model: str = "gpt-5"):
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    chunks = chunk_jsonl_for_openai(jsonl_file, max_tokens=max_tokens, model=model)
    
    for i, chunk in tqdm(enumerate(chunks)):
        print(f"Processing chunk {i+1}")
        
        response = client.beta.chat.completions.parse(
            model=model,
            messages=[
                {"role": "system", "content": "You are an assistant that extracts Armenian epigraphic terms."},
                {"role": "user", "content": f"""
                {zero_shot_prompting(chunk, terms_list)}
                """}
            ],
            response_format=ExtractionResult
        ).choices[0].message.parsed
        print(type(response)) 
        terms_only = {"terms": [term.model_dump() for term in response.terms]}  # convert Pydantic objects to dict

        out_file = Path(output_dir) / f"extraction_chunk_{i+1}.json"
        with open(out_file, "w", encoding="utf-8") as f:
            import json
            json.dump(terms_only, f, ensure_ascii=False, indent=2)

# %%
from tqdm import tqdm

for file_name in tqdm(df['source_file'].unique()):
    df_file=df[df['source_file']==file_name]
    df_file_path=f"C:/Users/Kamal/OneDrive/Documents/GitHub/dhlab-epigraphy-studies/preprocessing/Text Cleaning/temp/{file_name.replace('.txt','')}_cleaned.jsonl"
    if not os.path.exists(df_file_path):
        os.makedirs(os.path.dirname(df_file_path), exist_ok=True)
    df_file.to_json(df_file_path,orient='records',lines=True,force_ascii=False)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
# 100%|██████████| 37/37 [00:01<00:00, 27.04it/s]

# %%
for file_name in tqdm(os.listdir('temp')):
    name=file_name.replace('_cleaned.jsonl','')
    file_name="temp/"+file_name
    if not 'Divan_Prak10' in name:
        extract_terms_and_save(file_name,name,terms_list=terms_list,max_tokens=50000)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# 7it [17:23, 149.11s/it]
#   8%|▊         | 3/37 [17:23<3:17:09, 347.93s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# 11it [1:02:01, 338.33s/it]
#  11%|█         | 4/37 [1:19:25<13:09:55, 1436.22s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# 16it [55:00, 206.26s/it]
#  14%|█▎        | 5/37 [2:14:25<17:59:34, 2024.20s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# 12it [41:26, 207.19s/it]
#  16%|█▌        | 6/37 [2:55:51<18:40:00, 2167.75s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# 16it [41:16, 154.79s/it]
#  19%|█▉        | 7/37 [3:37:08<18:51:21, 2262.70s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# 12it [31:29, 157.45s/it]
#  22%|██▏       | 8/37 [4:08:37<17:18:35, 2148.81s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# 8it [16:29, 123.71s/it]
#  24%|██▍       | 9/37 [4:25:07<13:58:34, 1796.94s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# <class '__main__.ExtractionResult'>
# Processing chunk 17
# <class '__main__.ExtractionResult'>
# Processing chunk 18
# <class '__main__.ExtractionResult'>
# Processing chunk 19
# <class '__main__.ExtractionResult'>
# Processing chunk 20
# <class '__main__.ExtractionResult'>
# Processing chunk 21
# <class '__main__.ExtractionResult'>
# Processing chunk 22
# <class '__main__.ExtractionResult'>
# Processing chunk 23
# <class '__main__.ExtractionResult'>
# Processing chunk 24
# <class '__main__.ExtractionResult'>
# Processing chunk 25
# <class '__main__.ExtractionResult'>
# Processing chunk 26
# 26it [59:02, 136.24s/it]
#  27%|██▋       | 10/37 [5:24:09<17:26:10, 2324.84s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# 5it [06:41, 80.29s/it]
#  30%|██▉       | 11/37 [5:30:51<12:35:56, 1744.48s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# 2it [03:31, 105.97s/it]
#  32%|███▏      | 12/37 [5:34:23<8:54:31, 1282.86s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# 1it [04:14, 254.45s/it]
#  35%|███▌      | 13/37 [5:38:37<6:29:23, 973.47s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# 1it [02:49, 169.76s/it]
#  38%|███▊      | 14/37 [5:41:27<4:40:33, 731.88s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# 15it [26:20, 105.33s/it]
#  41%|████      | 15/37 [6:07:47<6:01:46, 986.67s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# <class '__main__.ExtractionResult'>
# Processing chunk 17
# <class '__main__.ExtractionResult'>
# Processing chunk 18
# <class '__main__.ExtractionResult'>
# Processing chunk 19
# <class '__main__.ExtractionResult'>
# Processing chunk 20
# <class '__main__.ExtractionResult'>
# Processing chunk 21
# <class '__main__.ExtractionResult'>
# Processing chunk 22
# <class '__main__.ExtractionResult'>
# Processing chunk 23
# <class '__main__.ExtractionResult'>
# Processing chunk 24
# <class '__main__.ExtractionResult'>
# Processing chunk 25
# <class '__main__.ExtractionResult'>
# Processing chunk 26
# <class '__main__.ExtractionResult'>
# Processing chunk 27
# <class '__main__.ExtractionResult'>
# Processing chunk 28
# <class '__main__.ExtractionResult'>
# Processing chunk 29
# <class '__main__.ExtractionResult'>
# Processing chunk 30
# <class '__main__.ExtractionResult'>
# Processing chunk 31
# <class '__main__.ExtractionResult'>
# Processing chunk 32
# <class '__main__.ExtractionResult'>
# Processing chunk 33
# <class '__main__.ExtractionResult'>
# Processing chunk 34
# <class '__main__.ExtractionResult'>
# Processing chunk 35
# <class '__main__.ExtractionResult'>
# Processing chunk 36
# <class '__main__.ExtractionResult'>
# Processing chunk 37
# <class '__main__.ExtractionResult'>
# Processing chunk 38
# <class '__main__.ExtractionResult'>
# Processing chunk 39
# <class '__main__.ExtractionResult'>
# Processing chunk 40
# 40it [1:13:07, 109.69s/it]
#  43%|████▎     | 16/37 [7:20:54<11:42:45, 2007.88s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# 10it [14:55, 89.56s/it]
#  46%|████▌     | 17/37 [7:35:50<9:17:59, 1673.96s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# 2it [02:59, 89.74s/it]
#  49%|████▊     | 18/37 [7:38:49<6:28:02, 1225.41s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# <class '__main__.ExtractionResult'>
# Processing chunk 17
# <class '__main__.ExtractionResult'>
# Processing chunk 18
# <class '__main__.ExtractionResult'>
# Processing chunk 19
# <class '__main__.ExtractionResult'>
# Processing chunk 20
# <class '__main__.ExtractionResult'>
# Processing chunk 21
# <class '__main__.ExtractionResult'>
# Processing chunk 22
# <class '__main__.ExtractionResult'>
# Processing chunk 23
# <class '__main__.ExtractionResult'>
# Processing chunk 24
# <class '__main__.ExtractionResult'>
# Processing chunk 25
# <class '__main__.ExtractionResult'>
# Processing chunk 26
# 26it [25:35, 59.04s/it]
#  51%|█████▏    | 19/37 [8:04:24<6:35:29, 1318.32s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# 3it [04:09, 83.06s/it]
#  54%|█████▍    | 20/37 [8:08:34<4:42:37, 997.52s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 1
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# <class '__main__.ExtractionResult'>
# Processing chunk 17
# <class '__main__.ExtractionResult'>
# Processing chunk 18
# <class '__main__.ExtractionResult'>
# Processing chunk 19
# <class '__main__.ExtractionResult'>
# Processing chunk 20
# <class '__main__.ExtractionResult'>
# Processing chunk 21
# <class '__main__.ExtractionResult'>
# Processing chunk 22
# <class '__main__.ExtractionResult'>
# Processing chunk 23
# <class '__main__.ExtractionResult'>
# Processing chunk 24
# <class '__main__.ExtractionResult'>
# Processing chunk 25
# <class '__main__.ExtractionResult'>
# Processing chunk 26
# <class '__main__.ExtractionResult'>
# Processing chunk 27
# <class '__main__.ExtractionResult'>
# Processing chunk 28
# <class '__main__.ExtractionResult'>
# Processing chunk 29
# <class '__main__.ExtractionResult'>
# Processing chunk 30
# <class '__main__.ExtractionResult'>
# Processing chunk 31
# <class '__main__.ExtractionResult'>
# Processing chunk 32
# <class '__main__.ExtractionResult'>
# Processing chunk 33
# <class '__main__.ExtractionResult'>
# Processing chunk 34
# <class '__main__.ExtractionResult'>
# Processing chunk 35
# <class '__main__.ExtractionResult'>
# Processing chunk 36
# <class '__main__.ExtractionResult'>
# Processing chunk 37
# <class '__main__.ExtractionResult'>
# Processing chunk 38
# <class '__main__.ExtractionResult'>
# Processing chunk 39
# <class '__main__.ExtractionResult'>
# Processing chunk 40
# <class '__main__.ExtractionResult'>
# Processing chunk 41
# <class '__main__.ExtractionResult'>
# Processing chunk 42
# <class '__main__.ExtractionResult'>
# Processing chunk 43
# <class '__main__.ExtractionResult'>
# Processing chunk 44
# <class '__main__.ExtractionResult'>
# Processing chunk 45
# <class '__main__.ExtractionResult'>
# Processing chunk 46
# <class '__main__.ExtractionResult'>
# Processing chunk 47
# <class '__main__.ExtractionResult'>
# Processing chunk 48
# <class '__main__.ExtractionResult'>
# Processing chunk 49
# <class '__main__.ExtractionResult'>
# Processing chunk 50
# <class '__main__.ExtractionResult'>
# Processing chunk 51
# <class '__main__.ExtractionResult'>
# Processing chunk 52
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
extract_terms_and_save("filtered_corpus.jsonl","complete_ext_0",terms_list=terms_list,max_tokens=50000)
# Out:
# 0it [00:00, ?it/s]
# Processing chunk 1
# 1it [01:54, 114.96s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 2
# 2it [04:08, 125.64s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 3
# 3it [05:29, 105.34s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 4
# 4it [07:03, 101.02s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 5
# 5it [10:00, 128.25s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 6
# 6it [12:06, 127.45s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 7
# 7it [15:27, 151.48s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 8
# 8it [17:05, 134.70s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 9
# 9it [18:58, 127.90s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 10
# 10it [21:15, 130.55s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 11
# 11it [23:25, 130.39s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 12
# 12it [24:50, 116.61s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 13
# 13it [27:30, 129.68s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 14
# 14it [30:40, 148.13s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 15
# 15it [33:06, 147.28s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 16
# 16it [35:23, 144.28s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 17
# 17it [37:26, 137.94s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 18
# 18it [39:49, 139.46s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 19
# 19it [42:34, 146.96s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 20
# 20it [44:52, 144.33s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 21
# 21it [47:51, 154.72s/it]
# <class '__main__.ExtractionResult'>
# Processing chunk 22
# 22it [49:33, 135.14s/it]
# <class '__main__.ExtractionResult'>
